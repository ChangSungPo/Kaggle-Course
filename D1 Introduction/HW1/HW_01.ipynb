# %%
import numpy as np
import pandas as pd
import time

# %% [markdown]
# # Hw01
# ## 作業目標：
# 1. 熟悉 Numpy, Pandas 的操作，並比較兩者的處理速度
# ## 作業重點：
# 1. 使用 Numpy, Pandas 分別計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間
# 2. 利用以下方式篩選離群值(option)：
# * feature 的平均值組成一個高維向量 Vec
# * 計算每個 sample 與 Vec 的距離
# * 計算距離的平均值、標準差，將距離平均值超過三個標準差的點當作離群值刪除
# * __請將刪除離群值後的 dataframe 取名為 df_after_delete__

# %%
# 讀取 homework.csv
""" Your Code Here: 讀取 homework.csv"""
df = pd.read_csv("E:\GitHub\Kaggle-Course\homework.csv")
df
# Out:
#            col0      col1      col2      col3      col4      col5      col6  \
# 0     -0.037418 -0.423133 -1.066878  0.463263 -0.130916 -1.153970 -0.598449
# 1      0.818413 -1.120974 -0.581785 -1.280338 -0.713844  1.698914 -0.832480
# 2     -2.090596 -0.868769 -1.778862  0.666989 -1.357663  0.433514 -1.617890
# 3     -0.289783  1.151368  1.105835 -0.309009  0.186021  0.625453 -1.357677
# 4      0.393337 -1.279473 -0.380730 -3.059202 -1.027667  0.121893  0.088561
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.169373 -1.659422  1.407234  0.625086 -1.779651  0.684514 -0.564882
# 99996  0.151488 -0.419368  0.077559 -0.997915 -1.871504 -2.338928 -1.914960
# 99997  1.208199 -1.139107  0.074972  0.371717  0.176787 -0.523450  1.561540
# 99998  0.038288  0.784779 -0.557020  2.462814  1.129594 -1.292801 -0.650390
# 99999 -0.017763  0.077523 -2.197524 -0.572833  0.476823  0.217154  0.006123
#
#            col7      col8      col9  ...     col70     col71     col72  \
# 0     -0.327957 -0.007907 -0.464428  ...  0.222763 -1.229966 -0.667184
# 1     -0.313192 -1.036266 -1.098621  ... -0.445329 -0.693601  0.795167
# 2     -1.220858 -0.566980 -1.237635  ...  1.152130 -0.058108 -0.105104
# 3      0.308579 -0.380738  1.335565  ... -0.683605  0.905133  1.328116
# 4     -0.444649  0.643246 -0.258456  ... -0.030803 -1.994453 -0.304141
# ...         ...       ...       ...  ...       ...       ...       ...
# 99995 -0.159244  0.861659  0.476870  ... -0.226039  1.396990  0.559320
# 99996 -2.855910  0.738012 -0.174478  ... -1.465184  0.402564  0.220336
# 99997  1.371943 -1.379962 -1.025441  ...  1.928941 -0.331970  0.573593
# 99998  0.715064 -1.328429  0.120543  ... -0.723951  0.122555 -1.811966
# 99999  1.996641 -0.389060  0.095060  ...  0.680210 -0.572903 -1.494582
#
#           col73     col74     col75     col76     col77     col78     col79
# 0     -0.102731 -1.310584 -0.702787  2.059981  0.608418 -0.020808  1.783352
# 1     -1.051140  1.285994  0.653626  1.396237  0.080399  1.377073 -0.794819
# 2      1.080918  0.924454 -0.019370 -0.948623 -0.981408 -0.251559  0.345169
# 3      0.529399 -0.443334  1.276279  2.503925  0.613427  0.358716 -0.958212
# 4     -1.626619 -0.737330  0.276077 -0.052384  0.645169 -0.728073 -0.051508
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.195908  0.486600 -1.544905 -1.052251  1.152265 -0.603716  1.214425
# 99996 -0.065954  1.597364  0.512378 -0.935301  0.152723 -0.134673 -0.591142
# 99997  0.163113  1.672773 -2.370009  0.746834  1.793470  1.268034 -0.520627
# 99998 -0.859171  0.828031  0.699950 -1.044509 -1.729967  1.211119 -0.157613
# 99999  1.278799 -0.569146 -0.013218  1.113988  0.275856 -1.133910  0.013100
#
# [100000 rows x 80 columns]

# %% [markdown]
# ## 1. 使用 Numpy, Pandas 分別計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間

# %%
# -------------- Numpy --------------
arr = np.array(df, dtype = 'float')

start = time.time()
""" Your Code Here: 用 Numpy 計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間"""
print(np.mean(arr, axis=0))
print(np.median(arr, axis=0))
print(np.max(arr, axis=0))
print(np.min(arr, axis=0))
end = time.time()
print(f'Numpy has done in {(end - start):.4f} sec.')

# -------------- Pandas --------------
start = time.time()
""" Your Code Here: 用 Pandas 計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間"""
print(df.mean())
print(df.median())
print(df.max())
print(df.min())
end = time.time()
print(f'Pandas has done in {(end - start):.4f} sec.')
# Out:
# [-9.82440251e-04 -1.77224635e-03 -6.65403110e-05  1.26022920e-03
#   4.44959155e-03  2.38206778e-03 -2.80442920e-03 -3.06814939e-03
#  -1.73568173e-03 -3.82597707e-04 -5.88477525e-03 -1.53677799e-03
#   5.65191191e-03  1.67027447e-03  4.68598249e-04  1.66740584e-03
#   4.49762841e-03 -5.33212045e-03 -1.97537149e-03  1.90114858e-03
#  -4.67319802e-03  1.55474524e-03  6.10056599e-04  1.94206920e-03
#   9.41469475e-04  2.77154555e-03 -7.70304175e-04  3.73557893e-03
#  -1.72283717e-03 -4.15402843e-03  3.59962747e-04 -6.35695789e-03
#   6.34763327e-03  1.10664034e-03  2.56787143e-03  6.89109963e-03
#  -1.92120552e-03 -7.99733861e-04  1.02444676e-03  4.68409976e-03
#  -3.27519170e-03  4.35651780e-03  6.27003290e-03 -3.31394520e-04
#   2.48493852e-03  1.27516330e-03 -5.74782786e-03 -2.16072370e-03
#  -3.38533629e-03  1.99165233e-03  4.99043664e-05 -9.05954425e-04
#   5.81826569e-04  6.52742094e-03  2.47171081e-03  2.70274412e-03
#   3.42303528e-03 -1.56751276e-03 -1.46920101e-03 -6.63072824e-04
#   5.12780271e-03 -4.87116009e-03  3.09814008e-03  2.64484732e-03
#  -1.29498715e-03 -2.68806462e-05 -2.51275528e-03  1.03877554e-03
#  -3.97768098e-04  3.45657347e-03  1.81933059e-03  1.48882809e-03
#  -4.01865049e-03 -9.77380101e-04  3.34522027e-03  3.52204243e-03
#  -2.01930306e-03 -3.71643866e-03  4.45780202e-03  4.13974495e-03]
# [-0.00207976 -0.00181176 -0.00506582  0.00378     0.0055833   0.00056566
#  -0.00492561 -0.0005372  -0.00713846  0.00288221 -0.00296164 -0.00392981
#   0.00833445  0.00010494  0.00557953 -0.00216583  0.00244901 -0.00484225
#  -0.00276189  0.00436581 -0.00131562 -0.00022349  0.00025643  0.00045073
#   0.00101398  0.00208247  0.00243975  0.00461892 -0.00361106 -0.00125298
#   0.00065079 -0.0037731   0.00954716 -0.00057374  0.00406635  0.00341948
#  -0.00737725 -0.0039097  -0.00090433  0.00820978 -0.00418882  0.00328936
#   0.00365975 -0.00477365  0.00349119 -0.0018743  -0.00653978 -0.00411172
#  -0.00431662  0.00092947 -0.00053582  0.00387306  0.00195246  0.00511417
#   0.00231852  0.00548009  0.00620755 -0.00341272 -0.00474059  0.00044666
#   0.00514273 -0.01196147  0.00354542  0.00106644  0.00135637  0.0050868
#  -0.00296084 -0.00392622  0.00065659  0.00110936  0.0023786   0.00182747
#  -0.00303032  0.0007255   0.00236082  0.00135579 -0.0031762  -0.00717375
#   0.00504717  0.00455633]
# [4.2929709  4.34030082 4.91504425 4.0773889  4.0560379  4.39005642
#  4.06004738 4.35115723 4.64759686 4.43616581 4.33731734 4.40421784
#  4.52032427 4.02578118 4.39406813 4.21412347 4.6061393  4.75831195
#  4.22019407 4.09190967 4.72061963 4.36142597 4.3992233  4.25966303
#  4.04553357 4.64920335 4.46654072 4.70724387 4.39367974 4.28587009
#  4.44939769 4.0731636  4.77931089 4.20067782 4.41906835 4.36051452
#  4.74634455 4.36573373 4.80285029 4.29978655 4.50705655 4.32997431
#  4.75257996 4.38621786 4.4516925  4.30247435 4.00404987 4.07718597
#  4.19040554 4.24722376 4.0752005  4.34736148 4.15889642 4.42740136
#  4.7727053  4.18640483 4.18996161 4.6838504  4.43234756 4.04318428
#  4.17740382 4.23849105 4.04055094 4.66461497 4.42597077 4.29156727
#  4.30138427 4.19666633 4.38890809 3.97425959 4.27083092 4.26642044
#  4.05983187 4.55604092 4.22102317 3.97975961 4.34852196 4.15919489
#  4.38234368 4.86982459]
# [-4.69880156 -4.48578572 -4.40358705 -4.4885497  -4.57655538 -4.67110786
#  -4.38842472 -4.37926348 -4.28027875 -4.10182933 -4.86188402 -4.57272005
#  -4.21912821 -4.05696806 -4.05689096 -4.51059338 -4.15696155 -3.90278096
#  -4.28376858 -4.67064511 -4.03576088 -4.18877953 -4.08952725 -4.06169884
#  -4.56727272 -4.10041052 -4.41769591 -4.40412021 -4.03182592 -4.19095814
#  -4.17179938 -4.28805368 -4.05756936 -4.19254857 -4.14291475 -4.12041058
#  -3.98940546 -4.56908785 -4.45144629 -4.18401083 -4.13411333 -4.08374861
#  -4.70910766 -4.38239679 -4.25407984 -4.27750468 -4.44194212 -4.4527689
#  -4.10490694 -4.16970558 -5.36902531 -4.27697953 -4.25807161 -4.37717353
#  -4.29117529 -4.37443464 -4.28757723 -4.17032775 -4.35998019 -4.29467537
#  -4.09429536 -4.56259309 -4.41024729 -4.48533596 -4.40776056 -4.36170916
#  -4.02340208 -4.2768813  -4.22441142 -4.51352576 -4.20747398 -4.47417031
#  -4.19034821 -3.93607239 -4.56041627 -4.53372391 -4.12394403 -4.59758563
#  -4.15929742 -4.49186772]
# Numpy has done in 0.0888 sec.
# col0    -0.000982
# col1    -0.001772
# col2    -0.000067
# col3     0.001260
# col4     0.004450
#            ...
# col75    0.003522
# col76   -0.002019
# col77   -0.003716
# col78    0.004458
# col79    0.004140
# Length: 80, dtype: float64
# col0    -0.002080
# col1    -0.001812
# col2    -0.005066
# col3     0.003780
# col4     0.005583
#            ...
# col75    0.001356
# col76   -0.003176
# col77   -0.007174
# col78    0.005047
# col79    0.004556
# Length: 80, dtype: float64
# col0     4.292971
# col1     4.340301
# col2     4.915044
# col3     4.077389
# col4     4.056038
#            ...
# col75    3.979760
# col76    4.348522
# col77    4.159195
# col78    4.382344
# col79    4.869825
# Length: 80, dtype: float64
# col0    -4.698802
# col1    -4.485786
# col2    -4.403587
# col3    -4.488550
# col4    -4.576555
#            ...
# col75   -4.533724
# col76   -4.123944
# col77   -4.597586
# col78   -4.159297
# col79   -4.491868
# Length: 80, dtype: float64
# Pandas has done in 0.1326 sec.

# %% [markdown]
# ## 2. 利用以下方式篩選離群值(option)：
# * feature 的平均值組成一個高維向量 Vec
# * 計算每個 sample 與 Vec 的距離
# * 計算距離的平均值、標準差，將距離平均值超過三個標準差的點當作離群值刪除
# * __請將刪除離群值後的 dataframe 取名為 df_after_delete__

# %%
# 計算各個 sample 與 Vec 之距離
n_samples, n_features =df.shape
""" Your Code Here: 計算各個 sample 與 Vec 之距離"""
means = np.tile(df.mean(), n_samples).reshape((n_samples, n_features))
distance = np.sum((arr - means) ** 2, axis = 1)
distance = np.sqrt(distance)
# 計算 distance 的 mean, std, 並篩選離群值
""" Your Code Here: 計算 distance 的 mean, std, 並篩選離群值"""
distance_mean = np.mean(distance)
distance_std = np.std(distance)
outlier_idx = np.where(np.abs(distance - distance_mean) > distance_std * 3)[0]
# 刪除離群值
""" Your Code Here: 刪除離群值"""
df_after_delete = df.drop(index = outlier_idx).reset_index(drop = True)
# Out:
# ' Your Code Here: 刪除離群值'

# %%
distance = np.sum((arr - means) ** 2, axis = 1)
distance = np.sqrt(distance)
distance
# Out:
# array([ 7.43005179,  8.64902617,  9.21974377, ...,  9.51953581,
#        10.44008995,  8.85172863])

# %%
distance_mean = np.mean(distance)
distance_std = np.std(distance)
outlier_idx = np.where(np.abs(distance - distance_mean) > distance_std * 3)[0]
outlier_idx
# Out:
# array([   85,   162,   317,   694,   724,   789,  1082,  1175,  1367,
#         1418,  1565,  2370,  2551,  3113,  3400,  3711,  3726,  5434,
#         5490,  5690,  5830,  6949,  6957,  7044,  7060,  7311,  7899,
#         8252,  8623,  9381,  9490,  9528, 10053, 10281, 10402, 11118,
#        11159, 12324, 12503, 12684, 12747, 13066, 13645, 13954, 14008,
#        14857, 14865, 14931, 15463, 15557, 16581, 16938, 17926, 18256,
#        19127, 19683, 19898, 19924, 19960, 20729, 21184, 21859, 22374,
#        22555, 22691, 22743, 22885, 23159, 23415, 23911, 23999, 24395,
#        24736, 26361, 26448, 26611, 26707, 26789, 27504, 27730, 27965,
#        28015, 29537, 29854, 30545, 30930, 30933, 31519, 31718, 31851,
#        32238, 32318, 32627, 32646, 32677, 32842, 33134, 33320, 33444,
#        33458, 33994, 34064, 34716, 35014, 35112, 35293, 35710, 35747,
#        36129, 36148, 36491, 37191, 37569, 37963, 38590, 38623, 39440,
#        40154, 40333, 40788, 41264, 41410, 41521, 41675, 41720, 41788,
#        42091, 43066, 43284, 43693, 43801, 44368, 45014, 45245, 45573,
#        45816, 46093, 46219, 46944, 47381, 47876, 47878, 48006, 48036,
#        49485, 49769, 50296, 50887, 51628, 51809, 52444, 52468, 52584,
#        52773, 53310, 53549, 54291, 54364, 54416, 54859, 55213, 55613,
#        55977, 56350, 56661, 56988, 57278, 57345, 57500, 58163, 58215,
#        58366, 58730, 59189, 59312, 59368, 60725, 61353, 61415, 61429,
#        61886, 61954, 62464, 62606, 62656, 62696, 62831, 62964, 63172,
#        63183, 63933, 64293, 64406, 65008, 65578, 65806, 65901, 67208,
#        67229, 67526, 68280, 68778, 68857, 68956, 69138, 69318, 69536,
#        70603, 71058, 71861, 72581, 72647, 72835, 73603, 73795, 73849,
#        73901, 74216, 74368, 74472, 75246, 75370, 75375, 75495, 75699,
#        76131, 76597, 77180, 78016, 78048, 78568, 78697, 78731, 78953,
#        79035, 79373, 80450, 80795, 82075, 82091, 82839, 82872, 82882,
#        83608, 84214, 84299, 84794, 85280, 86139, 86265, 86631, 86684,
#        87117, 87136, 87151, 87196, 87453, 87601, 87752, 87813, 87997,
#        88402, 88406, 88547, 89011, 90010, 90203, 90650, 91107, 91177,
#        91499, 91664, 91683, 92536, 92648, 93542, 94276, 94688, 94874,
#        95173, 95198, 95565, 95598, 96153, 96824, 98041, 98122, 99530,
#        99911], dtype=int64)

# %%
df_after_delete = df.drop(index = outlier_idx).reset_index(drop = True)
df_after_delete
# Out:
#            col0      col1      col2      col3      col4      col5      col6  \
# 0     -0.037418 -0.423133 -1.066878  0.463263 -0.130916 -1.153970 -0.598449
# 1      0.818413 -1.120974 -0.581785 -1.280338 -0.713844  1.698914 -0.832480
# 2     -2.090596 -0.868769 -1.778862  0.666989 -1.357663  0.433514 -1.617890
# 3     -0.289783  1.151368  1.105835 -0.309009  0.186021  0.625453 -1.357677
# 4      0.393337 -1.279473 -0.380730 -3.059202 -1.027667  0.121893  0.088561
# ...         ...       ...       ...       ...       ...       ...       ...
# 99706  1.169373 -1.659422  1.407234  0.625086 -1.779651  0.684514 -0.564882
# 99707  0.151488 -0.419368  0.077559 -0.997915 -1.871504 -2.338928 -1.914960
# 99708  1.208199 -1.139107  0.074972  0.371717  0.176787 -0.523450  1.561540
# 99709  0.038288  0.784779 -0.557020  2.462814  1.129594 -1.292801 -0.650390
# 99710 -0.017763  0.077523 -2.197524 -0.572833  0.476823  0.217154  0.006123
#
#            col7      col8      col9  ...     col70     col71     col72  \
# 0     -0.327957 -0.007907 -0.464428  ...  0.222763 -1.229966 -0.667184
# 1     -0.313192 -1.036266 -1.098621  ... -0.445329 -0.693601  0.795167
# 2     -1.220858 -0.566980 -1.237635  ...  1.152130 -0.058108 -0.105104
# 3      0.308579 -0.380738  1.335565  ... -0.683605  0.905133  1.328116
# 4     -0.444649  0.643246 -0.258456  ... -0.030803 -1.994453 -0.304141
# ...         ...       ...       ...  ...       ...       ...       ...
# 99706 -0.159244  0.861659  0.476870  ... -0.226039  1.396990  0.559320
# 99707 -2.855910  0.738012 -0.174478  ... -1.465184  0.402564  0.220336
# 99708  1.371943 -1.379962 -1.025441  ...  1.928941 -0.331970  0.573593
# 99709  0.715064 -1.328429  0.120543  ... -0.723951  0.122555 -1.811966
# 99710  1.996641 -0.389060  0.095060  ...  0.680210 -0.572903 -1.494582
#
#           col73     col74     col75     col76     col77     col78     col79
# 0     -0.102731 -1.310584 -0.702787  2.059981  0.608418 -0.020808  1.783352
# 1     -1.051140  1.285994  0.653626  1.396237  0.080399  1.377073 -0.794819
# 2      1.080918  0.924454 -0.019370 -0.948623 -0.981408 -0.251559  0.345169
# 3      0.529399 -0.443334  1.276279  2.503925  0.613427  0.358716 -0.958212
# 4     -1.626619 -0.737330  0.276077 -0.052384  0.645169 -0.728073 -0.051508
# ...         ...       ...       ...       ...       ...       ...       ...
# 99706  1.195908  0.486600 -1.544905 -1.052251  1.152265 -0.603716  1.214425
# 99707 -0.065954  1.597364  0.512378 -0.935301  0.152723 -0.134673 -0.591142
# 99708  0.163113  1.672773 -2.370009  0.746834  1.793470  1.268034 -0.520627
# 99709 -0.859171  0.828031  0.699950 -1.044509 -1.729967  1.211119 -0.157613
# 99710  1.278799 -0.569146 -0.013218  1.113988  0.275856 -1.133910  0.013100
#
# [99711 rows x 80 columns]
